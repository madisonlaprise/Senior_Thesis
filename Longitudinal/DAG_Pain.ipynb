# %%
import pandas as pd
import numpy as np
from pgmpy.estimators import HillClimbSearch, BicScore
from pgmpy.models import BayesianNetwork
import matplotlib.pyplot as plt
import networkx as nx

df = pd.read_csv(r'C:\Users\MadiL\Thesis CodeBase\Longitudinal\Individual Questions\aggregated_data_wide.csv')

# %%
import ges as GES
from pgmpy.estimators import BicScore
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
import networkx as nx

# Dataset: Use the combined dataset from T1, T2, and T3.
# Define time points (T1, T2, T3)
T1_columns = [col for col in df.columns if col.startswith('2019-07')]
T2_columns = [col for col in df.columns if col.startswith('2020-01')]
T3_columns = [col for col in df.columns if col.startswith('2020-05')]

# Combine time point data
T1_data = df[T1_columns].dropna()
T2_data = df[T2_columns].dropna()
T3_data = df[T3_columns].dropna()

from pgmpy.estimators import PC
from pgmpy.estimators import BicScore
import matplotlib.pyplot as plt
import networkx as nx

# Combine data from T1, T2, and T3
combined_data = pd.concat([T1_data, T2_data, T3_data], axis=0)
print("Combined shape before cleaning:", combined_data.shape)

# Fill missing values with column means
combined_data = combined_data.fillna(combined_data.mean())

# Use the PC Algorithm for structure learning
pc = PC(data=combined_data)
model_combined = pc.estimate()
print("Learned model edges with PC Algorithm:", model_combined.edges())

# Visualize the learned structure
def visualize_dag(model, title="Bayesian Network (DAG)"):
    # Convert to a NetworkX graph
    G = nx.DiGraph()
    G.add_edges_from(model.edges())
    
    # Plot the DAG
    plt.figure(figsize=(10, 8))
    pos = nx.spring_layout(G, seed=42)
    nx.draw_networkx_nodes(G, pos, node_color='lightblue', node_size=1000)
    nx.draw_networkx_edges(G, pos, arrowstyle='-|>', arrowsize=20, edge_color='gray')
    nx.draw_networkx_labels(G, pos, font_size=12, font_color='black')
    plt.title(title)
    plt.show()

visualize_dag(model_combined, title="Bayesian Network (Combined Data - PC Algorithm)")
# Out:
# Combined shape before cleaning: (1264, 168)
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      30 # Use the PC Algorithm for structure learning
#      31 pc = PC(data=combined_data)
# ---> 32 model_combined = pc.estimate()
#      33 print("Learned model edges with PC Algorithm:", model_combined.edges())
#      35 # Visualize the learned structure
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pgmpy\estimators\PC.py:181, in PC.estimate(self, variant, ci_test, max_cond_vars, return_type, significance_level, n_jobs, show_progress, **kwargs)
#     176     raise ValueError(
#     177         "For using Chi Square or Pearsonr, data argument must be specified"
#     178     )
#     180 # Step 1: Run the PC algorithm to build the skeleton and get the separating sets.
# --> 181 skel, separating_sets = self.build_skeleton(
#     182     ci_test=ci_test,
#     183     max_cond_vars=max_cond_vars,
#     184     significance_level=significance_level,
#     185     variant=variant,
#     186     n_jobs=n_jobs,
#     187     show_progress=show_progress,
#     188     **kwargs,
#     189 )
#     191 if return_type.lower() == "skeleton":
#     192     return skel, separating_sets
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pgmpy\estimators\PC.py:309, in PC.build_skeleton(self, ci_test, max_cond_vars, significance_level, variant, n_jobs, show_progress, **kwargs)
#     302 for u, v in graph.edges():
#     303     for separating_set in chain(
#     304         combinations(set(neighbors[u]) - set([v]), lim_neighbors),
#     305         combinations(set(neighbors[v]) - set([u]), lim_neighbors),
#     306     ):
#     307         # If a conditioning set exists remove the edge, store the
#     308         # separating set and move on to finding conditioning set for next edge.
# --> 309         if ci_test(
#     310             u,
#     311             v,
#     312             separating_set,
#     313             data=self.data,
#     314             independencies=self.independencies,
#     315             significance_level=significance_level,
#     316             **kwargs,
#     317         ):
#     318             separating_sets[frozenset((u, v))] = separating_set
#     319             graph.remove_edge(u, v)
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pgmpy\estimators\CITests.py:97, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      37 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      38     r"""
#      39     Chi-square conditional independence test.
#      40     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      95     False
#      96     """
# ---> 97     return power_divergence(
#      98         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      99     )
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pgmpy\estimators\CITests.py:550, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     548 chi = 0
#     549 dof = 0
# --> 550 for z_state, df in data.groupby(Z):
#     551     try:
#     552         c, _, d, _ = stats.chi2_contingency(
#     553             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     554         )
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\groupby\groupby.py:1217, in <genexpr>(.0)
#    1207     warnings.warn(
#    1208         "Creating a Groupby object with a length-1 list-like "
#    1209         "level parameter will yield indexes as tuples in a future version. "
#    (...)
#    1213         stacklevel=find_stack_level(),
#    1214     )
#    1215 if isinstance(keys, list) and len(keys) == 1:
#    1216     # GH#42795 - when keys is a list, return tuples even when length is 1
# -> 1217     result = (((key,), group) for key, group in result)
#    1218 return result
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\groupby\ops.py:620, in BaseGrouper.get_iterator(self, data, axis)
#     618 splitter = self._get_splitter(data, axis=axis)
#     619 keys = self.group_keys_seq
# --> 620 yield from zip(keys, splitter)
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\groupby\ops.py:1150, in DataSplitter.__iter__(self)
#    1149 def __iter__(self) -> Iterator:
# -> 1150     sdata = self._sorted_data
#    1152     if self.ngroups == 0:
#    1153         # we are inside a generator, rather than raise StopIteration
#    1154         # we merely return signal the end
#    1155         return
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\groupby\ops.py:1164, in DataSplitter._sorted_data(self)
#    1162 @cache_readonly
#    1163 def _sorted_data(self) -> NDFrameT:
# -> 1164     return self.data.take(self._sort_idx, axis=self.axis)
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\MadiL\Thesis CodeBase\thesisenv\Lib\site-packages\pandas\core\array_algos\take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:
